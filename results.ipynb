# %% [markdown]
# ### Baseline 10 Weighted Loss vs Weightless Loss

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "baseline-10-b32-e20-gamma_default-use_weighted_loss-vdw8g6my", "validation_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Baseline 10 Weighted Loss\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [04:18<00:00, 67.90it/s]

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "baseline-10-b32-e20-gamma_default-h_size768-use_weighted_loss-1o82hs5n", "validation_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Baseline 10 Weighted Loss Hidden Size 768\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [05:46<00:00, 50.60it/s]

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "baseline-10-b32-e20-gamma_default-h_size768-1p3i0gie", "validation_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Baseline 10 Hidden Size 768\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [06:07<00:00, 47.74it/s]

# %% [markdown]
# ### Sequence Labelling 10 Weighted vs Weightless Loss, Freeze DNABERT

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "sequence-labelling-10-use_weighted_loss-freeze.base-1uk28zd2", "eval_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Sequence Labelling Tiny, Freeze DNABERT, Weighted Loss\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [04:46<00:00, 61.20it/s]

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "sequence-labelling-10-freeze.base-2ld8wy02", "validation_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Sequence Labelling Tiny, Freeze DNABERT, Non Weighted Loss\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [04:42<00:00, 62.10it/s]

# %% [markdown]
# ### Sequence Labelling 10 Freeze vs Fine Tuning, all with Weighted Loss

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "sequence-labelling-10-use_weighted_loss-base-k8c76dwa", "eval_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Sequence Labelling Tiny, Fine Tuned DNABERT, Weighted Loss\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [04:52<00:00, 59.98it/s]

# %%
from utils.confusion_matrix import create_confusion_matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import os

validation_log_path = os.path.join("run", "sequence-labelling-10-use_weighted_loss-freeze.base-1uk28zd2", "eval_log.19.csv")
preds, targets = create_confusion_matrix(validation_log_path)
fig, ax = plt.subplots(constrained_layout=True, figsize=(8,4))
ax = sns.heatmap(confusion_matrix(targets, preds, labels=[0,1,2,3,4,5,6,7]), annot=True, cmap='Blues')
ax.set_title('Sequence Labelling Tiny, Freeze DNABERT, Weighted Loss\n\n')
ax.set_xlabel('Predicted Label \n')
ax.set_ylabel('Target Label ')

## Display the visualization of the Confusion Matrix.

plt.show()
# Out:
# Processing: 100%|██████████| 17539/17539 [04:38<00:00, 62.97it/s]
